# %%
#List, Dictionary, tuple, Sets, Conditional statement. # Mutable and unmutable DS

# %%
import timeit
list_creation = "[i for i in range(1000)]"
list_time = timeit.timeit(stmt = list_creation, number=10000)
print(list_time)
# Out:
# 1.1464919090000052

# %%
import timeit
set_creation = "(i for i in range(1000))"
set_time = timeit.timeit(stmt=set_creation, number=10000)
print(set_time)
# Out:
# 0.004605986999877132

# %%
import timeit
dict_creation = "{i: i*2 for i in range(1000)}"
dict_time = timeit.timeit(stmt=dict_creation, number= 10000)
print(f"Time to create dictionary: {dict_time} seconds")
# Out:
# Time to create dictionary: 0.5512036380000609 seconds

# %%
x=3.4
reminder = x % 1
if reminder < .5 :
  print("Reminder does not honor the pact")
else:
  print("reminder is in the range")
# Out:
# Reminder does not honor the pact

# %%
# def printNum(num):
#   print("My favourite number is ", num)

# print(printNum(5))

def getMeList(list):
  for item in list:
    print(item)

getMeList([1,4,4,8,9,20])
# Out:
# 1
# 4
# 4
# 8
# 9
# 20

# %%
from google.colab import files
files.upload()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.plot(x, y, marker='o', linestyle='-', color='c', label='y = x^2')

plt.title('Line Graph of Squares')
plt.xlabel('x values')
plt.ylabel('y values (x squared)')

plt.legend()

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[2,4,6,8,10]

plt.plot(x, y, marker='o', linestyle='--', color='b', label='y = 2x')
plt.title('graph potraying linear relationship ')
plt.xlabel('x values')
plt.ylabel('y label')

plt.legend()

plt.grid(True)
plt.show()
